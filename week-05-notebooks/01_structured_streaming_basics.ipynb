# %% [markdown]
# # Structured Streaming Basics
#
# Auto Loader ingestion and continuous execution behavior.

# %%
stream_df = (
    spark.readStream
        .format('cloudFiles')
        .option('cloudFiles.format', 'json')
        .option('cloudFiles.schemaLocation', '/schemas/events')
        .load('/raw/events')
)

display(stream_df)
