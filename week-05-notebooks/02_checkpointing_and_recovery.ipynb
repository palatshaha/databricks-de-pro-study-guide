# %% [markdown]
# # Checkpointing and Recovery
#
# Exactly-once semantics and restart behavior.

# %%
query = (
    stream_df.writeStream
        .format('delta')
        .option('checkpointLocation', '/checkpoints/events')
        .outputMode('append')
        .start('/delta/bronze/events')
)

query
