# %% [markdown]
# # Deployment and Idempotency
#
# Repeatable deployments and idempotent writes.

# %%
spark.sql("""
MERGE INTO silver_events t
USING staging_events s
ON t.id = s.id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *
""")
