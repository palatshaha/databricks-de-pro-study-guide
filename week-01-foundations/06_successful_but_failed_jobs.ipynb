# %% [markdown]
# # 06 – Successful but Failed Jobs

# %%
late = spark.createDataFrame(
    [(999999, "click", "2024-12-31T23:59:00")],
    ["id", "event", "ts"]
)
late.write.mode("append").saveAsTable("de_pro_week1.bronze_events")

# %% [markdown]
# ## Exam Takeaway
# Success includes correctness and timeliness.
