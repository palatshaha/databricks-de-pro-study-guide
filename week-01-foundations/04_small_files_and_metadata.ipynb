# %% [markdown]
# # 04 – Small Files and Metadata Explosion

# %%
df = spark.range(0, 100_000).repartition(200)
df.write.mode("overwrite").saveAsTable("de_pro_week1.small_files")

# %%
DESCRIBE DETAIL de_pro_week1.small_files

# %%
OPTIMIZE de_pro_week1.small_files

# %% [markdown]
# ## Exam Takeaway
# Small files are a governance and planning problem.
