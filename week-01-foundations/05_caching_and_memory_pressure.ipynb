# %% [markdown]
# # 05 – Caching and Memory Pressure

# %%
CACHE TABLE de_pro_week1.silver_target

# %%
SELECT group_id, COUNT(*) FROM de_pro_week1.write_heavy GROUP BY group_id

# %%
UNCACHE TABLE de_pro_week1.silver_target

# %% [markdown]
# ## Exam Takeaway
# Caching competes with execution memory.
