# %% [markdown]
# # Compliance and Retention
#
# Logical vs physical deletion, retention policies, and auditability.

# %%
-- Logical delete
DELETE FROM main.customers WHERE customer_id = 123;

# %%
-- Physical delete (use with caution)
VACUUM main.customers RETAIN 0 HOURS;

# %%
-- Inspect history
DESCRIBE HISTORY main.customers;
