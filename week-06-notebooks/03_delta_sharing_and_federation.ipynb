# %% [markdown]
# # Delta Sharing and Lakehouse Federation
#
# Create shares, recipients, and explore federated access.

# %%
-- Create share
CREATE SHARE gold_share;

# %%
-- Add table to share
ALTER SHARE gold_share ADD TABLE main.gold.sales_summary;
