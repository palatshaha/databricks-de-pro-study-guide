# %% [markdown]
# # Unity Catalog Permission Reachability
#
# Demonstrates hierarchical permission evaluation in Unity Catalog and why SELECT without USAGE results in invisible objects.

# %%
# Grant SELECT without USAGE
print('Table is not visible')

# %%
# Grant USAGE on catalog and schema
print('Table becomes visible')
