# %% [markdown]
# # Managed vs External Tables
#
# Compare lifecycle, VACUUM behavior, and responsibility boundaries.

# %%
# Create managed table
print('Dropping table deletes data')

# %%
# Create external table
print('Dropping table preserves data')
