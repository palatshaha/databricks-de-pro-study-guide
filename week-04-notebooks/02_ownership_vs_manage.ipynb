# %% [markdown]
# # Ownership vs MANAGE Privilege
#
# Shows the difference between object ownership and the MANAGE privilege in Databricks governance.

# %%
# Create view owned by user
print('Only owner can replace view')

# %%
# Transfer ownership to group
print('Group members can now modify')
