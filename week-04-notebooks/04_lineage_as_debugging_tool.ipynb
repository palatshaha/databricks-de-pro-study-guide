# %% [markdown]
# # Lineage as Debugging Tool
#
# Use lineage to trace downstream impact from Gold to Bronze.

# %%
# Simulate dashboard anomaly
print('Trace lineage graph')

# %%
# Identify upstream transformation
print('Locate source')
