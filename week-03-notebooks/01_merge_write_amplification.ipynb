# %% [markdown]
# # MERGE Write Amplification
#
# Observe how MERGE rewrites files over time even when row counts stay stable.

# %%
# Setup sample Delta table
print('Run this in Databricks Community or workspace')

# %%
# Repeated MERGE runs
print('Observe file counts and runtime drift')
