# %% [markdown]
# # OPTIMIZE as Maintenance
#
# OPTIMIZE improves layout temporarily but does not fix write patterns.

# %%
# Create fragmented table
print('Create fragmented Delta table')

# %%
# OPTIMIZE and rewrite
print('Observe performance regression')
