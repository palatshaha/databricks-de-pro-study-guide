# %% [markdown]
# # Caching and Memory Pressure
#
# Caching competes with shuffle and streaming memory.

# %%
# Cache table
print('Cache table')

# %%
# Competing workload
print('Observe memory pressure')
