# %% [markdown]
# # Schema Evolution Risks

# %%
spark.range(0,10).withColumn("a", rand())     .write.mode("overwrite").saveAsTable("de_pro_week2.schema_test")

# %%
spark.range(0,10).withColumn("a", rand()).withColumn("b", rand())     .write.mode("append").saveAsTable("de_pro_week2.schema_test")

# %% [markdown]
# ## Exam Takeaway
# Blind schema evolution propagates downstream risk.
